# %%
# !wget https://bit.ly/fruits_300_data -O fruits_300.npy
# Out:
# --2025-06-10 17:06:17--  https://bit.ly/fruits_300_data
# bit.ly (bit.ly) 해석 중... 67.199.248.11, 67.199.248.10
# 다음으로 연결 중: bit.ly (bit.ly)|67.199.248.11|:443... 실패: 연결이 거부됨.
# 다음으로 연결 중: bit.ly (bit.ly)|67.199.248.10|:443... 실패: 연결이 거부됨.
